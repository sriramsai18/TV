# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tvmarketing.csv")

# %%
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df.tail()
# Out:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.sample(n=5)
# Out:
#         TV  Sales
# 155    4.1    3.2
# 79   116.0   11.0
# 23   228.3   15.5
# 66    31.5    9.5
# 45   175.1   14.9

# %%
df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# TV       0.0
# Sales    0.0
# dtype: float64

# %%
sns.boxplot(df["TV"])
# Out:
# <Axes: ylabel='TV'>

# %%
sns.boxplot(df["Sales"])
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Scatter plot is used to check the variance of the data ,wheather it has high variance or low variance or medium variance of datapoints. this pair plot is linear so we can use the linear regression

# %%
sns.heatmap(df.corr(), cmap = 'YlGnBu', annot = True)
plt.show()

# %%
#y = mx+c (simple linear equation format)
x = df['TV']
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state = 100)

# %%
x_train.head()
# Out:
# 168    215.4
# 112    175.7
# 171    164.5
# 181    218.5
# 7      120.2
# Name: TV, dtype: float64

# %%
x_train.shape
# Out:
# (160,)

# %%
x_test.shape
# Out:
# (40,)

# %%
x_test.head()
# Out:
# 126      7.8
# 104    238.2
# 99     135.2
# 92     217.7
# 111    241.7
# Name: TV, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x_train = x_train.values.reshape(-1,1)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test.values.reshape(-1,1))

# %%
y_pred
# Out:
# array([ 7.47266432, 18.09635222, 13.3470473 , 17.15110221, 18.25773636,
#        16.64850586, 13.53148632, 16.2242961 , 17.09115952, 17.10960343,
#        12.51707168, 17.69519733,  9.70437654, 15.77242049, 11.13377899,
#        11.45654728, 14.01563877, 14.96088877, 14.65195341, 12.31879973,
#        17.01277294, 13.07961071, 16.12285464, 15.27443512, 15.6387022 ,
#        17.27098757, 17.2479327 , 10.58507289, 15.6387022 , 12.78911924,
#        10.26691557, 10.29458142, 12.69228876, 15.80008634,  9.41849605,
#        12.66923388, 11.59487655, 14.87789121, 17.36781806, 16.02141317])

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.7)


plt.plot(np.unique(y_test), np.poly1d(np.polyfit(y_test, y_pred, 1))(np.unique(y_test)),
         color='red', linestyle='--')


plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Actual Values")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Absolute Error (MAE): 2.4983195821565403
# Mean Squared Error (MSE): 9.687069547890871
